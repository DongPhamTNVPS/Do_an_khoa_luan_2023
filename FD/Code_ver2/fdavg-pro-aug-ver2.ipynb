# %% [markdown]
# # 1. Cài đặt thư viện

# %%
# %%capture
# !pip install torchinfo

# %%
# thư viện xử lí dữ liệu
import pandas as pd
import numpy as np

# trực quan dữ liệu
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from PIL import Image
from sklearn.model_selection import train_test_split as tts

# Torch
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader
from torchinfo import summary
from torchvision.models import vit_b_16, ViT_B_16_Weights

# Metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report

# os quản lí thư mục
import os

# OrderedDict , cung cấp dữ liệu giống như từ điển (các cặp khoá-giá trị)
from collections import OrderedDict

# tqdm tạo thanh tiến trình (progress bar) giúp theo dõi tiến độ của một vòng lặp
from tqdm.auto import tqdm

# Path
from pathlib import Path

# random
import random

# typing
from typing import Dict, List

# warnings
import warnings
warnings.filterwarnings("ignore")

from copy import deepcopy

import torch.optim as optim
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # 2. Tiền xử lí dữ liệu

# %% [markdown]
# ## 2.1 Load data

# %%
# Tổng số hình ảnh
IMAGE_PATH = Path("/kaggle/input/data-da-lieu-aug2/file_data_aug")

IMAGE_PATH_LIST = list(IMAGE_PATH.glob("*/*/*.jpeg"))

print(f'Total Images = {len(IMAGE_PATH_LIST)}')
# Out:
# Total Images = 891

# %%
classes = os.listdir(IMAGE_PATH)
classes = sorted(classes)
classes
# Out:
# ['acne', 'bags', 'redness']

# %% [markdown]
# ## 2.2 Thống kê số liệu

# %%
# Số lượng hình ảnh mỗi lớp

print("**" * 20)
print(" " * 10, f"Total Classes = {len(classes)}")
print("**" * 20)

for c in classes:
    total_images_class = list(Path(os.path.join(IMAGE_PATH, c)).glob("*/*.jpeg"))
    print(f"* {c}: {len(total_images_class)} images")
# Out:
# ****************************************
#            Total Classes = 3
# ****************************************
# * acne: 318 images
# * bags: 273 images
# * redness: 300 images

# %% [markdown]
# ## 2.3 visualize

# %%
# xem 3 số hình ảnh của mỗi lớp
NUM_IMAGES = 3

fig, ax = plt.subplots(nrows = len(classes), ncols = NUM_IMAGES, figsize = (10,15))
p = 0
for c in classes:
    total_images_class = list(Path(os.path.join(IMAGE_PATH, c)).glob("*/*.jpeg"))
    images_selected = random.choices(total_images_class, k = NUM_IMAGES)
    
    for i,img_path in enumerate(images_selected):
        img_bgr = cv2.imread(str(img_path))
        img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
        ax[p,i].imshow(img_rgb)
        ax[p,i].axis("off")
        ax[p,i].set_title(f"Class: {c}\nShape: {img_rgb.shape}", fontsize = 8, fontweight = "bold", color = "black")
        
    p += 1
    
fig.tight_layout()
fig.show()

# %% [markdown]
# ## 2.4 Tạo liên kết dữ liệu

# %%
images_path = [None] * len(IMAGE_PATH_LIST)
labels = [None] * len(IMAGE_PATH_LIST)

for i,image_path in enumerate(IMAGE_PATH_LIST):
    images_path[i] = image_path
    labels[i] = image_path.parent.parent.stem
    
df_path_and_label = pd.DataFrame({'path':images_path, 
                                  'label':labels})
df_path_and_label.head()
# Out:
#                                                 path label
# 0  /kaggle/input/data-da-lieu-aug2/file_data_aug/...  acne
# 1  /kaggle/input/data-da-lieu-aug2/file_data_aug/...  acne
# 2  /kaggle/input/data-da-lieu-aug2/file_data_aug/...  acne
# 3  /kaggle/input/data-da-lieu-aug2/file_data_aug/...  acne
# 4  /kaggle/input/data-da-lieu-aug2/file_data_aug/...  acne

# %% [markdown]
# ## 2.5 Chia dữ liệu train , test
#
#       * train = 70%
#       * valid = 15%
#       * test = 15%

# %%
SEED = 123

df_train, df_rest = tts(df_path_and_label, 
                        test_size = 0.3, 
                        random_state = SEED, 
                        stratify = df_path_and_label["label"])

df_val, df_test = tts(df_rest, 
                      test_size = 0.5, 
                      random_state = SEED, 
                      stratify = df_rest["label"])

# %%
# gán số cho lable
label_map = dict(zip(classes, range(0, len(classes))))
label_map
# Out:
# {'acne': 0, 'bags': 1, 'redness': 2}

# %% [markdown]
# # 3. Model Vit không áp dụng học liên kết

# %% [markdown]
# ## 3.1 Áp dụng các trọng số model vit trước đó

# %%
weights = ViT_B_16_Weights.DEFAULT
auto_transforms = weights.transforms()
auto_transforms
# Out:
# ImageClassification(
#     crop_size=[224]
#     resize_size=[256]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BILINEAR
# )

# %% [markdown]
# ## 3.2 Dataset

# %%
class CustomDataset(Dataset):
    def __init__(self, df:pd.DataFrame, transforms, label_map:dict):
        self.df = df
        self.transforms = transforms
        self.label_map = label_map
        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        df_new = self.df.copy()
        df_new = df_new.reset_index(drop = True)
        df_new["label"] = df_new["label"].map(self.label_map)
        image_path = df_new.iloc[idx, 0]
        image = Image.open(image_path).convert("RGB")
        image = self.transforms(image)
        label = df_new.iloc[idx, 1]
        
        return image,label

# %%
train_dataset = CustomDataset(df_train, auto_transforms, label_map)
valid_dataset = CustomDataset(df_val, auto_transforms, label_map)

# %% [markdown]
# ## 3.3 DataLoader

# %%
BATCH_SIZE = 1
NUM_WORKERS = os.cpu_count()

train_dataloader = DataLoader(dataset = train_dataset, 
                              batch_size = BATCH_SIZE, 
                              shuffle = True, 
                              num_workers = NUM_WORKERS)
valid_dataloader = DataLoader(dataset = valid_dataset, 
                              batch_size = BATCH_SIZE, 
                              shuffle = True, 
                              num_workers = NUM_WORKERS)

# %%
# Let's visualize the dimensions of a batch.
batch_images, batch_labels = next(iter(train_dataloader))

batch_images.shape, batch_labels.shape
# Out:
# (torch.Size([1, 3, 224, 224]), torch.Size([1]))

# %% [markdown]
# ### visualize image(3 layer)

# %%
def vis(img):
    fig, axs = plt.subplots(1, 3, figsize=(20, 25))
    axs[0].imshow(img[0])
    axs[1].imshow(img[1])
    axs[2].imshow(img[2])
train_features, train_labels = next(iter(train_dataloader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
img = train_features[0].cpu().squeeze()
#label = train_labels[0][0].cpu()
vis(img)
plt.show()
# print(f"Label: {label}")
#plt.imshow(label)
# Out:
# Feature batch shape: torch.Size([1, 3, 224, 224])
# Labels batch shape: torch.Size([1])

# %%
# GPU
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
# sử dụng các trọng số đã được đạo tạo trước 
model = vit_b_16(weights = weights)
# Out:
# Downloading: "https://download.pytorch.org/models/vit_b_16-c867db91.pth" to /root/.cache/torch/hub/checkpoints/vit_b_16-c867db91.pth
# 100%|██████████| 330M/330M [00:04<00:00, 75.8MB/s]

# %%
summary(model = model, 
        input_size = [1, 3, 224, 224], 
        col_names = ["input_size", "output_size", "num_params", "trainable"], 
        col_width = 15, 
        row_settings = ["var_names"])
# Out:
# ========================================================================================================================
# Layer (type (var_name))                                      Input Shape     Output Shape    Param #         Trainable
# ========================================================================================================================
# VisionTransformer (VisionTransformer)                        [1, 3, 224, 224] [1, 1000]       768             True
# ├─Conv2d (conv_proj)                                         [1, 3, 224, 224] [1, 768, 14, 14] 590,592         True
# ├─Encoder (encoder)                                          [1, 197, 768]   [1, 197, 768]   151,296         True
# │    └─Dropout (dropout)                                     [1, 197, 768]   [1, 197, 768]   --              --
# │    └─Sequential (layers)                                   [1, 197, 768]   [1, 197, 768]   --              True
# │    │    └─EncoderBlock (encoder_layer_0)                   [1, 197, 768]   [1, 197, 768]   7,087,872       True
# │    │    └─EncoderBlock (encoder_layer_1)                   [1, 197, 768]   [1, 197, 768]   7,087,872       True
# │    │    └─EncoderBlock (encoder_layer_2)                   [1, 197, 768]   [1, 197, 768]   7,087,872       True
# │    │    └─EncoderBlock (encoder_layer_3)                   [1, 197, 768]   [1, 197, 768]   7,087,872       True
# │    │    └─EncoderBlock (encoder_layer_4)                   [1, 197, 768]   [1, 197, 768]   7,087,872       True
# │    │    └─EncoderBlock (encoder_layer_5)                   [1, 197, 768]   [1, 197, 768]   7,087,872       True
# │    │    └─EncoderBlock (encoder_layer_6)                   [1, 197, 768]   [1, 197, 768]   7,087,872       True
# │    │    └─EncoderBlock (encoder_layer_7)                   [1, 197, 768]   [1, 197, 768]   7,087,872       True
# │    │    └─EncoderBlock (encoder_layer_8)                   [1, 197, 768]   [1, 197, 768]   7,087,872       True
# │    │    └─EncoderBlock (encoder_layer_9)                   [1, 197, 768]   [1, 197, 768]   7,087,872       True
# │    │    └─EncoderBlock (encoder_layer_10)                  [1, 197, 768]   [1, 197, 768]   7,087,872       True
# │    │    └─EncoderBlock (encoder_layer_11)                  [1, 197, 768]   [1, 197, 768]   7,087,872       True
# │    └─LayerNorm (ln)                                        [1, 197, 768]   [1, 197, 768]   1,536           True
# ├─Sequential (heads)                                         [1, 768]        [1, 1000]       --              True
# │    └─Linear (head)                                         [1, 768]        [1, 1000]       769,000         True
# ========================================================================================================================
# Total params: 86,567,656
# Trainable params: 86,567,656
# Non-trainable params: 0
# Total mult-adds (M): 173.23
# ========================================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 104.09
# Params size (MB): 232.27
# Estimated Total Size (MB): 336.96
# ========================================================================================================================

# %% [markdown]
# ### Chúng tôi sẽ cố định các tham số của lớp conv_proj và encoder layers

# %%
for param in model.conv_proj.parameters():
    param.requires_grad = False

# %%
for param in model.encoder.parameters():
    param.requires_grad = False

# %%
# Let's see if the parameters were frozen.
summary(model = model, 
        input_size = [1,3,224,224], 
        col_names = ["input_size", "output_size", "num_params", "trainable"], 
        col_width = 15,
        row_settings = ["var_names"])
# Out:
# ========================================================================================================================
# Layer (type (var_name))                                      Input Shape     Output Shape    Param #         Trainable
# ========================================================================================================================
# VisionTransformer (VisionTransformer)                        [1, 3, 224, 224] [1, 1000]       768             Partial
# ├─Conv2d (conv_proj)                                         [1, 3, 224, 224] [1, 768, 14, 14] (590,592)       False
# ├─Encoder (encoder)                                          [1, 197, 768]   [1, 197, 768]   151,296         False
# │    └─Dropout (dropout)                                     [1, 197, 768]   [1, 197, 768]   --              --
# │    └─Sequential (layers)                                   [1, 197, 768]   [1, 197, 768]   --              False
# │    │    └─EncoderBlock (encoder_layer_0)                   [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_1)                   [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_2)                   [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_3)                   [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_4)                   [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_5)                   [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_6)                   [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_7)                   [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_8)                   [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_9)                   [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_10)                  [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_11)                  [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    └─LayerNorm (ln)                                        [1, 197, 768]   [1, 197, 768]   (1,536)         False
# ├─Sequential (heads)                                         [1, 768]        [1, 1000]       --              True
# │    └─Linear (head)                                         [1, 768]        [1, 1000]       769,000         True
# ========================================================================================================================
# Total params: 86,567,656
# Trainable params: 769,768
# Non-trainable params: 85,797,888
# Total mult-adds (M): 173.23
# ========================================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 104.09
# Params size (MB): 232.27
# Estimated Total Size (MB): 336.96
# ========================================================================================================================

# %%
output_shape = len(classes)

model.heads = nn.Sequential(OrderedDict([('head', nn.Linear(in_features = 768, 
                                                            out_features = output_shape))]))

# %%
# One last time let's take a look if the last layer was modified.
summary(model = model, 
        input_size = [1,3,224,224], 
        col_names = ["input_size", "output_size", "num_params", "trainable"], 
        col_width = 15,
        row_settings = ["var_names"])
# Out:
# ========================================================================================================================
# Layer (type (var_name))                                      Input Shape     Output Shape    Param #         Trainable
# ========================================================================================================================
# VisionTransformer (VisionTransformer)                        [1, 3, 224, 224] [1, 3]          768             Partial
# ├─Conv2d (conv_proj)                                         [1, 3, 224, 224] [1, 768, 14, 14] (590,592)       False
# ├─Encoder (encoder)                                          [1, 197, 768]   [1, 197, 768]   151,296         False
# │    └─Dropout (dropout)                                     [1, 197, 768]   [1, 197, 768]   --              --
# │    └─Sequential (layers)                                   [1, 197, 768]   [1, 197, 768]   --              False
# │    │    └─EncoderBlock (encoder_layer_0)                   [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_1)                   [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_2)                   [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_3)                   [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_4)                   [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_5)                   [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_6)                   [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_7)                   [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_8)                   [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_9)                   [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_10)                  [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    │    └─EncoderBlock (encoder_layer_11)                  [1, 197, 768]   [1, 197, 768]   (7,087,872)     False
# │    └─LayerNorm (ln)                                        [1, 197, 768]   [1, 197, 768]   (1,536)         False
# ├─Sequential (heads)                                         [1, 768]        [1, 3]          --              True
# │    └─Linear (head)                                         [1, 768]        [1, 3]          2,307           True
# ========================================================================================================================
# Total params: 85,800,963
# Trainable params: 3,075
# Non-trainable params: 85,797,888
# Total mult-adds (M): 172.47
# ========================================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 104.09
# Params size (MB): 229.20
# Estimated Total Size (MB): 333.89
# ========================================================================================================================

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = 0.01)

# %% [markdown]
# # 3.5 Các hàm chính

# %%
def train_step(model:torch.nn.Module, 
               dataloader:torch.utils.data.DataLoader, 
               loss_fn:torch.nn.Module, 
               optimizer:torch.optim.Optimizer):
    
    model.train()
    
    train_loss = 0.
    train_accuracy = 0.
    
    for batch,(X,y) in enumerate(dataloader):
        X,y = X.to(device), y.to(device)
        optimizer.zero_grad()
        y_pred_logit = model(X)
        loss = loss_fn(y_pred_logit, y)
        train_loss += loss.item()
        
        loss.backward()
        optimizer.step()
        
        y_pred_prob = torch.softmax(y_pred_logit, dim = 1)
        y_pred_class = torch.argmax(y_pred_prob, dim = 1)
        train_accuracy += accuracy_score(y.cpu().numpy(), 
                                         y_pred_class.detach().cpu().numpy())
        
    train_loss = train_loss/len(dataloader)
    train_accuracy = train_accuracy/len(dataloader)
    
    return train_loss, train_accuracy

# %%
def valid_step(model:torch.nn.Module, 
               dataloader:torch.utils.data.DataLoader, 
               loss_fn:torch.nn.Module):
    
    model.eval()
    
    valid_loss = 0.
    valid_accuracy = 0.
    
    with torch.inference_mode():
        for batch,(X,y) in enumerate(dataloader):
            X,y = X.to(device), y.to(device)
            y_pred_logit = model(X)
            loss = loss_fn(y_pred_logit, y)
            valid_loss += loss.item()
            
            y_pred_prob = torch.softmax(y_pred_logit, dim = 1)
            y_pred_class = torch.argmax(y_pred_prob, dim = 1)
            
            valid_accuracy += accuracy_score(y.cpu().numpy(), y_pred_class.detach().cpu().numpy())
            
    valid_loss = valid_loss/len(dataloader)
    valid_accuracy = valid_accuracy/len(dataloader)
    
    return valid_loss, valid_accuracy

# %%
def save_checkpoint(filename, model, loss, epoch, optimizer, metric):
    state = {"filename":filename, 
             "model":model.state_dict(), 
             "loss":loss, 
             "epoch":epoch, 
             "optimizer":optimizer.state_dict(), 
             "metric":metric}
    
    torch.save(state, filename)

# %%
def train(model:torch.nn.Module, 
          train_dataloader:torch.utils.data.DataLoader, 
          valid_dataloader:torch.utils.data.DataLoader, 
          loss_fn:torch.nn.Module, 
          optimizer:torch.optim.Optimizer, 
          epochs:int = 10):
    
    results = {"train_loss":[], 
               "train_accuracy":[], 
               "valid_loss":[], 
               "valid_accuracy":[]}
    
    best_valid_loss = float("inf")
    
    for epoch in tqdm(range(epochs)):
        train_loss, train_accuracy = train_step(model = model, 
                                                dataloader = train_dataloader, 
                                                loss_fn = loss_fn, 
                                                optimizer = optimizer)
        
        valid_loss, valid_accuracy = valid_step(model = model, 
                                                dataloader = valid_dataloader, 
                                                loss_fn = loss_fn)
        
        if valid_loss < best_valid_loss:
            best_valid_loss = valid_loss
            file_name = "best_model.pth"
            save_checkpoint(file_name, model, best_valid_loss, epoch, optimizer, valid_accuracy)
            
        print(f"Epoch: {epoch + 1} | ", 
              f"Train Loss: {train_loss:.4f} | ", 
              f"Train Accuracy: {train_accuracy:.4f} | ", 
              f"Valid Loss: {valid_loss:.4f} | ", 
              f"Valid Accuracy: {valid_accuracy:.4f}")
        
        results["train_loss"].append(train_loss)
        results["train_accuracy"].append(train_accuracy)
        results["valid_loss"].append(valid_loss)
        results["valid_accuracy"].append(valid_accuracy)
        
    return results

# %%
EPOCHS = 100

torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

MODEL_RESULTS = train(model.to(device), 
                      train_dataloader, 
                      valid_dataloader, 
                      loss_fn, 
                      optimizer, 
                      EPOCHS)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 1 |  Train Loss: 2.9613 |  Train Accuracy: 0.3339 |  Valid Loss: 1.5776 |  Valid Accuracy: 0.2985
# Epoch: 2 |  Train Loss: 2.7208 |  Train Accuracy: 0.3644 |  Valid Loss: 2.3427 |  Valid Accuracy: 0.3060
# Epoch: 3 |  Train Loss: 2.3109 |  Train Accuracy: 0.3820 |  Valid Loss: 3.5764 |  Valid Accuracy: 0.3582
# Epoch: 4 |  Train Loss: 2.4344 |  Train Accuracy: 0.3772 |  Valid Loss: 5.4015 |  Valid Accuracy: 0.3358
# Epoch: 5 |  Train Loss: 2.4125 |  Train Accuracy: 0.3628 |  Valid Loss: 3.5629 |  Valid Accuracy: 0.3433
# Epoch: 6 |  Train Loss: 2.0488 |  Train Accuracy: 0.4093 |  Valid Loss: 2.2413 |  Valid Accuracy: 0.3507
# Epoch: 7 |  Train Loss: 1.9213 |  Train Accuracy: 0.4109 |  Valid Loss: 1.4832 |  Valid Accuracy: 0.2910
# Epoch: 8 |  Train Loss: 1.8837 |  Train Accuracy: 0.4543 |  Valid Loss: 1.9776 |  Valid Accuracy: 0.3433
# Epoch: 9 |  Train Loss: 1.9440 |  Train Accuracy: 0.4254 |  Valid Loss: 3.1598 |  Valid Accuracy: 0.3209
# Epoch: 10 |  Train Loss: 2.0928 |  Train Accuracy: 0.4093 |  Valid Loss: 1.9887 |  Valid Accuracy: 0.3433
# Epoch: 11 |  Train Loss: 1.9265 |  Train Accuracy: 0.4591 |  Valid Loss: 1.9261 |  Valid Accuracy: 0.3358
# Epoch: 12 |  Train Loss: 1.9617 |  Train Accuracy: 0.4510 |  Valid Loss: 2.8409 |  Valid Accuracy: 0.3433
# Epoch: 13 |  Train Loss: 1.8910 |  Train Accuracy: 0.4222 |  Valid Loss: 3.0016 |  Valid Accuracy: 0.3358
# Epoch: 14 |  Train Loss: 1.9751 |  Train Accuracy: 0.4286 |  Valid Loss: 2.8745 |  Valid Accuracy: 0.3507
# Epoch: 15 |  Train Loss: 1.9128 |  Train Accuracy: 0.4366 |  Valid Loss: 1.5754 |  Valid Accuracy: 0.3209
# Epoch: 16 |  Train Loss: 1.8558 |  Train Accuracy: 0.4735 |  Valid Loss: 2.1734 |  Valid Accuracy: 0.3582
# Epoch: 17 |  Train Loss: 1.7643 |  Train Accuracy: 0.5040 |  Valid Loss: 2.3544 |  Valid Accuracy: 0.3582
# Epoch: 18 |  Train Loss: 1.5887 |  Train Accuracy: 0.5120 |  Valid Loss: 1.8602 |  Valid Accuracy: 0.3657
# Epoch: 19 |  Train Loss: 1.9043 |  Train Accuracy: 0.4831 |  Valid Loss: 2.2629 |  Valid Accuracy: 0.3209
# Epoch: 20 |  Train Loss: 1.9657 |  Train Accuracy: 0.4671 |  Valid Loss: 2.6685 |  Valid Accuracy: 0.3358
# Epoch: 21 |  Train Loss: 1.8202 |  Train Accuracy: 0.5008 |  Valid Loss: 2.6806 |  Valid Accuracy: 0.3433
# Epoch: 22 |  Train Loss: 1.6806 |  Train Accuracy: 0.4799 |  Valid Loss: 2.4610 |  Valid Accuracy: 0.3433
# Epoch: 23 |  Train Loss: 1.8589 |  Train Accuracy: 0.4655 |  Valid Loss: 2.0422 |  Valid Accuracy: 0.3209
# Epoch: 24 |  Train Loss: 1.6789 |  Train Accuracy: 0.4880 |  Valid Loss: 2.1543 |  Valid Accuracy: 0.3284
# Epoch: 25 |  Train Loss: 1.7239 |  Train Accuracy: 0.5040 |  Valid Loss: 2.9193 |  Valid Accuracy: 0.3582
# Epoch: 26 |  Train Loss: 1.5877 |  Train Accuracy: 0.5088 |  Valid Loss: 3.2531 |  Valid Accuracy: 0.3284
# Epoch: 27 |  Train Loss: 1.6225 |  Train Accuracy: 0.5120 |  Valid Loss: 2.5013 |  Valid Accuracy: 0.3134
# Epoch: 28 |  Train Loss: 1.6445 |  Train Accuracy: 0.4896 |  Valid Loss: 2.1890 |  Valid Accuracy: 0.3582
# Epoch: 29 |  Train Loss: 1.8996 |  Train Accuracy: 0.4607 |  Valid Loss: 2.0986 |  Valid Accuracy: 0.3507
# Epoch: 30 |  Train Loss: 1.5467 |  Train Accuracy: 0.5169 |  Valid Loss: 2.0095 |  Valid Accuracy: 0.2836
# Epoch: 31 |  Train Loss: 1.4825 |  Train Accuracy: 0.5249 |  Valid Loss: 1.8837 |  Valid Accuracy: 0.2985
# Epoch: 32 |  Train Loss: 1.4705 |  Train Accuracy: 0.5201 |  Valid Loss: 2.5420 |  Valid Accuracy: 0.3284
# Epoch: 33 |  Train Loss: 1.3855 |  Train Accuracy: 0.5233 |  Valid Loss: 3.1331 |  Valid Accuracy: 0.3134
# Epoch: 34 |  Train Loss: 1.4980 |  Train Accuracy: 0.5249 |  Valid Loss: 2.3625 |  Valid Accuracy: 0.3358
# Epoch: 35 |  Train Loss: 1.4185 |  Train Accuracy: 0.5554 |  Valid Loss: 2.3854 |  Valid Accuracy: 0.3284
# Epoch: 36 |  Train Loss: 1.5217 |  Train Accuracy: 0.5506 |  Valid Loss: 2.9077 |  Valid Accuracy: 0.3358
# Epoch: 37 |  Train Loss: 1.5203 |  Train Accuracy: 0.5104 |  Valid Loss: 2.3107 |  Valid Accuracy: 0.2985
# Epoch: 38 |  Train Loss: 1.3764 |  Train Accuracy: 0.5538 |  Valid Loss: 2.2022 |  Valid Accuracy: 0.2910
# Epoch: 39 |  Train Loss: 1.4547 |  Train Accuracy: 0.5474 |  Valid Loss: 2.1187 |  Valid Accuracy: 0.3657
# Epoch: 40 |  Train Loss: 1.5117 |  Train Accuracy: 0.5345 |  Valid Loss: 2.4559 |  Valid Accuracy: 0.3060
# Epoch: 41 |  Train Loss: 1.5386 |  Train Accuracy: 0.5008 |  Valid Loss: 3.4999 |  Valid Accuracy: 0.3358
# Epoch: 42 |  Train Loss: 1.4454 |  Train Accuracy: 0.5377 |  Valid Loss: 2.5669 |  Valid Accuracy: 0.3209
# Epoch: 43 |  Train Loss: 1.4337 |  Train Accuracy: 0.5522 |  Valid Loss: 4.4170 |  Valid Accuracy: 0.3358
# Epoch: 44 |  Train Loss: 1.4393 |  Train Accuracy: 0.5297 |  Valid Loss: 2.5765 |  Valid Accuracy: 0.3657
# Epoch: 45 |  Train Loss: 1.4871 |  Train Accuracy: 0.5425 |  Valid Loss: 2.2825 |  Valid Accuracy: 0.2836
# Epoch: 46 |  Train Loss: 1.3911 |  Train Accuracy: 0.5554 |  Valid Loss: 2.4094 |  Valid Accuracy: 0.3433
# Epoch: 47 |  Train Loss: 1.6043 |  Train Accuracy: 0.5522 |  Valid Loss: 2.2537 |  Valid Accuracy: 0.3284
# Epoch: 48 |  Train Loss: 1.4137 |  Train Accuracy: 0.5538 |  Valid Loss: 1.9163 |  Valid Accuracy: 0.2985
# Epoch: 49 |  Train Loss: 1.5251 |  Train Accuracy: 0.5570 |  Valid Loss: 2.5123 |  Valid Accuracy: 0.2910
# Epoch: 50 |  Train Loss: 1.5510 |  Train Accuracy: 0.5409 |  Valid Loss: 1.9505 |  Valid Accuracy: 0.3209
# Epoch: 51 |  Train Loss: 1.3975 |  Train Accuracy: 0.5474 |  Valid Loss: 2.2570 |  Valid Accuracy: 0.3284
# Epoch: 52 |  Train Loss: 1.3832 |  Train Accuracy: 0.5650 |  Valid Loss: 2.8667 |  Valid Accuracy: 0.3134
# Epoch: 53 |  Train Loss: 1.2919 |  Train Accuracy: 0.6003 |  Valid Loss: 2.4414 |  Valid Accuracy: 0.2836
# Epoch: 54 |  Train Loss: 1.4404 |  Train Accuracy: 0.5682 |  Valid Loss: 2.3653 |  Valid Accuracy: 0.2910
# Epoch: 55 |  Train Loss: 1.4872 |  Train Accuracy: 0.5859 |  Valid Loss: 2.6462 |  Valid Accuracy: 0.3433
# Epoch: 56 |  Train Loss: 1.3811 |  Train Accuracy: 0.5457 |  Valid Loss: 5.1173 |  Valid Accuracy: 0.3731
# Epoch: 57 |  Train Loss: 1.4418 |  Train Accuracy: 0.5730 |  Valid Loss: 3.2727 |  Valid Accuracy: 0.3134
# Epoch: 58 |  Train Loss: 1.1757 |  Train Accuracy: 0.5971 |  Valid Loss: 2.4826 |  Valid Accuracy: 0.3582
# Epoch: 59 |  Train Loss: 1.4719 |  Train Accuracy: 0.5682 |  Valid Loss: 3.6108 |  Valid Accuracy: 0.3358
# Epoch: 60 |  Train Loss: 1.2566 |  Train Accuracy: 0.5730 |  Valid Loss: 1.8912 |  Valid Accuracy: 0.3209
# Epoch: 61 |  Train Loss: 1.3141 |  Train Accuracy: 0.5538 |  Valid Loss: 3.5230 |  Valid Accuracy: 0.3060
# Epoch: 62 |  Train Loss: 1.4541 |  Train Accuracy: 0.5746 |  Valid Loss: 2.2140 |  Valid Accuracy: 0.3134
# Epoch: 63 |  Train Loss: 1.3235 |  Train Accuracy: 0.5650 |  Valid Loss: 3.2489 |  Valid Accuracy: 0.3731
# Epoch: 64 |  Train Loss: 1.3180 |  Train Accuracy: 0.5634 |  Valid Loss: 2.1357 |  Valid Accuracy: 0.2910
# Epoch: 65 |  Train Loss: 1.2484 |  Train Accuracy: 0.5730 |  Valid Loss: 2.6180 |  Valid Accuracy: 0.3582
# Epoch: 66 |  Train Loss: 1.1441 |  Train Accuracy: 0.5843 |  Valid Loss: 3.7424 |  Valid Accuracy: 0.3657
# Epoch: 67 |  Train Loss: 1.4886 |  Train Accuracy: 0.5762 |  Valid Loss: 2.6879 |  Valid Accuracy: 0.3806
# Epoch: 68 |  Train Loss: 1.4384 |  Train Accuracy: 0.5666 |  Valid Loss: 2.2795 |  Valid Accuracy: 0.2612
# Epoch: 69 |  Train Loss: 1.3140 |  Train Accuracy: 0.5971 |  Valid Loss: 2.5193 |  Valid Accuracy: 0.2836
# Epoch: 70 |  Train Loss: 1.3419 |  Train Accuracy: 0.6035 |  Valid Loss: 2.7752 |  Valid Accuracy: 0.2985
# Epoch: 71 |  Train Loss: 1.2932 |  Train Accuracy: 0.5843 |  Valid Loss: 2.4588 |  Valid Accuracy: 0.3060
# Epoch: 72 |  Train Loss: 1.2513 |  Train Accuracy: 0.5955 |  Valid Loss: 2.3844 |  Valid Accuracy: 0.2836
# Epoch: 73 |  Train Loss: 1.3270 |  Train Accuracy: 0.5762 |  Valid Loss: 3.0081 |  Valid Accuracy: 0.3507
# Epoch: 74 |  Train Loss: 1.1679 |  Train Accuracy: 0.6051 |  Valid Loss: 2.9434 |  Valid Accuracy: 0.3582
# Epoch: 75 |  Train Loss: 1.1919 |  Train Accuracy: 0.6421 |  Valid Loss: 2.4560 |  Valid Accuracy: 0.3284
# Epoch: 76 |  Train Loss: 1.2884 |  Train Accuracy: 0.5987 |  Valid Loss: 2.7899 |  Valid Accuracy: 0.3881
# Epoch: 77 |  Train Loss: 1.5176 |  Train Accuracy: 0.5762 |  Valid Loss: 2.3846 |  Valid Accuracy: 0.3209
# Epoch: 78 |  Train Loss: 1.2727 |  Train Accuracy: 0.6035 |  Valid Loss: 2.6280 |  Valid Accuracy: 0.3209
# Epoch: 79 |  Train Loss: 1.4107 |  Train Accuracy: 0.5939 |  Valid Loss: 2.4368 |  Valid Accuracy: 0.3060
# Epoch: 80 |  Train Loss: 1.3132 |  Train Accuracy: 0.6067 |  Valid Loss: 2.7909 |  Valid Accuracy: 0.3433
# Epoch: 81 |  Train Loss: 1.2330 |  Train Accuracy: 0.6148 |  Valid Loss: 2.5756 |  Valid Accuracy: 0.3284
# Epoch: 82 |  Train Loss: 1.4506 |  Train Accuracy: 0.5714 |  Valid Loss: 2.1739 |  Valid Accuracy: 0.3657
# Epoch: 83 |  Train Loss: 1.3023 |  Train Accuracy: 0.5682 |  Valid Loss: 2.8009 |  Valid Accuracy: 0.3060
# Epoch: 84 |  Train Loss: 1.3898 |  Train Accuracy: 0.5746 |  Valid Loss: 2.8773 |  Valid Accuracy: 0.3284
# Epoch: 85 |  Train Loss: 1.2018 |  Train Accuracy: 0.6372 |  Valid Loss: 3.0117 |  Valid Accuracy: 0.3582
# Epoch: 86 |  Train Loss: 1.1327 |  Train Accuracy: 0.6019 |  Valid Loss: 2.6183 |  Valid Accuracy: 0.3507
# Epoch: 87 |  Train Loss: 1.1738 |  Train Accuracy: 0.6083 |  Valid Loss: 2.2113 |  Valid Accuracy: 0.3284
# Epoch: 88 |  Train Loss: 1.5024 |  Train Accuracy: 0.6035 |  Valid Loss: 2.4975 |  Valid Accuracy: 0.3358
# Epoch: 89 |  Train Loss: 1.4276 |  Train Accuracy: 0.5923 |  Valid Loss: 3.5923 |  Valid Accuracy: 0.3284
# Epoch: 90 |  Train Loss: 1.3551 |  Train Accuracy: 0.5971 |  Valid Loss: 3.8440 |  Valid Accuracy: 0.3209
# Epoch: 91 |  Train Loss: 1.2264 |  Train Accuracy: 0.5891 |  Valid Loss: 2.3168 |  Valid Accuracy: 0.3433
# Epoch: 92 |  Train Loss: 1.2431 |  Train Accuracy: 0.5939 |  Valid Loss: 3.5768 |  Valid Accuracy: 0.3284
# Epoch: 93 |  Train Loss: 1.1807 |  Train Accuracy: 0.6228 |  Valid Loss: 2.5089 |  Valid Accuracy: 0.3060
# Epoch: 94 |  Train Loss: 1.2613 |  Train Accuracy: 0.5666 |  Valid Loss: 2.1957 |  Valid Accuracy: 0.3358
# Epoch: 95 |  Train Loss: 1.2450 |  Train Accuracy: 0.6100 |  Valid Loss: 3.2169 |  Valid Accuracy: 0.3582
# Epoch: 96 |  Train Loss: 1.3079 |  Train Accuracy: 0.5923 |  Valid Loss: 2.4583 |  Valid Accuracy: 0.3433
# Epoch: 97 |  Train Loss: 1.1925 |  Train Accuracy: 0.6148 |  Valid Loss: 2.2964 |  Valid Accuracy: 0.3433
# Epoch: 98 |  Train Loss: 1.3065 |  Train Accuracy: 0.6003 |  Valid Loss: 2.3471 |  Valid Accuracy: 0.3433
# Epoch: 99 |  Train Loss: 1.2470 |  Train Accuracy: 0.6067 |  Valid Loss: 2.8436 |  Valid Accuracy: 0.3358
# Epoch: 100 |  Train Loss: 1.1752 |  Train Accuracy: 0.6164 |  Valid Loss: 3.5717 |  Valid Accuracy: 0.3209

# %% [markdown]
# ## 3.6 Visualize loss vs accuracy

# %%
# Function to plot the loss and metric during each training epoch.
def loss_metric_curve_plot(model_results:Dict[str,List[float]]):
    
    train_loss = model_results["train_loss"]
    valid_loss = model_results["valid_loss"]
    
    train_accuracy = [float(value) for value in model_results["train_accuracy"]]
    valid_accuracy = [float(value) for value in model_results["valid_accuracy"]]
    
    fig,axes = plt.subplots(nrows = 1, ncols = 2, figsize = (10,4))
    axes = axes.flat
    
    axes[0].plot(train_loss, color = "red", label = "Train")
    axes[0].plot(valid_loss, color = "blue", label = "Valid")
    axes[0].set_title("CrossEntropyLoss", fontsize = 12, fontweight = "bold", color = "black")
    axes[0].set_xlabel("Epochs", fontsize = 10, fontweight = "bold", color = "black")
    axes[0].set_ylabel("Loss", fontsize = 10, fontweight = "bold", color = "black")
    axes[0].legend()
    
    axes[1].plot(train_accuracy, color = "red", label = "Train")
    axes[1].plot(valid_accuracy, color = "blue", label = "Valid")
    axes[1].set_title("Metric of performance: Accuracy", fontsize = 12, fontweight = "bold", color = "black")
    axes[1].set_xlabel("Epochs", fontsize = 10, fontweight = "bold", color = "black")
    axes[1].set_ylabel("Score", fontsize = 10, fontweight = "bold", color = "black")
    axes[1].legend()
    
    fig.tight_layout()
    fig.show()

# %%
loss_metric_curve_plot(MODEL_RESULTS)

# %%
checkpoint_path = "/kaggle/working/best_model.pth"
checkpoint = torch.load(checkpoint_path)

# %%
print(f'Best Loss: {checkpoint["loss"]}')
print(f'Epoch: {checkpoint["epoch"] + 1}')
print(f'Best Metric: {checkpoint["metric"]}')
# Out:
# Best Loss: 1.4832122631982636
# Epoch: 7
# Best Metric: 0.291044776119403

# %% [markdown]
# ## 3.7 test

# %%
# First of all, we create the Dataset, DataLoader
test_dataset = CustomDataset(df_test, auto_transforms, label_map)
test_dataloader = DataLoader(dataset = test_dataset, shuffle = False, num_workers = NUM_WORKERS)

# %%
# We define the model again with its respective modification.
loaded_model = vit_b_16()

loaded_model.heads = nn.Sequential(OrderedDict([('head',nn.Linear(in_features = 768, 
                                                                  out_features = output_shape))]))

loaded_model.load_state_dict(checkpoint["model"])

# We now infer
loaded_model.to(device)

loaded_model.eval()

y_pred_test = []

with torch.inference_mode():
    for X,y in tqdm(test_dataloader):
        X,y = X.to(device), y.to(device)
        y_pred_logit = loaded_model(X)
        y_pred_prob = torch.softmax(y_pred_logit, dim = 1)
        y_pred_class = torch.argmax(y_pred_prob, dim = 1)
        y_pred_test.append(y_pred_class.detach().cpu())
# Out:
#   0%|          | 0/134 [00:00<?, ?it/s]

# %%
y_pred_test = torch.cat(y_pred_test).numpy()

# %%
print(f'Accuracy = {round(accuracy_score(df_test["label"].map(label_map), y_pred_test), 4)}')
# Out:
# Accuracy = 0.3134

# %%
confusion_matrix_test = confusion_matrix(df_test["label"].map(label_map), y_pred_test)

# %%
fig,ax = plt.subplots(figsize = (15,4))
sns.heatmap(confusion_matrix_test, 
            cmap = 'coolwarm', 
            annot = True, 
            annot_kws = {"fontsize":9, "fontweight":"bold"}, 
            linewidths = 1.2, 
            linecolor = "black", 
            square = True, 
            xticklabels = classes, 
            yticklabels = classes, 
            cbar = False,
            ax = ax)
ax.set_title("Confusion Matrix Test", fontsize = 10, fontweight = "bold", color = "darkblue")
ax.tick_params('x',rotation = 90)
fig.show()

# %% [markdown]
# # 4. Model Vit Áp dụng học liên kết

# %% [markdown]
# ## 4.1 Chia data thành các node (khách hàng)

# %%
def simulate_data(dataset, num_nodes):
    points = np.random.randint(1, 5, size=num_nodes)
    points = points * len(dataset) / points.sum()
    points = points.astype(int)
    points[-1] += len(dataset) - points.sum()
    list_data = torch.utils.data.random_split(dataset, points)
    
    plt.title('data distribution all node')
    plt.bar(np.arange(len(points)), points)
    plt.show()
    
    return list_data

# %%
class Arguments():
    def __init__(self):
        self.mu = 2 # Proximal term
        self.q = 0 # Fair Resource Allocation
        
        self.B = 1 # local batch size
        
        self.E = 20 # local epoch
        self.n_iter = 15 # global epoch
        self.lr =  0.000008 # learning rate
        
        self.K = 5 # total node
        
        self.C = 0.1 # frac node
        self.verbose = False # verbose
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        

args = Arguments()

# %%
training_list_dataset = simulate_data(train_dataset, args.K)
valid_list_dataset = simulate_data(valid_dataloader, args.K)

# %%
training_sets = [DataLoader(dataset=data, batch_size=args.B, shuffle=True) for data in training_list_dataset]

# %%
valid_sets = [DataLoader(dataset=data, batch_size=args.B, shuffle=True) for data in valid_list_dataset]

# %% [markdown]
# ## 4.2 Các hàm chính của FD

# %%
# sử dụng các trọng số đã được đạo tạo trước
model = vit_b_16(weights = weights)

# %%
# đóng băng các tham số
for param in model.conv_proj.parameters():
    param.requires_grad = False

# %%
for param in model.encoder.parameters():
    param.requires_grad = False

# %%
output_shape = len(classes)

model.heads = nn.Sequential(OrderedDict([('head', nn.Linear(in_features = 768, 
                                                            out_features = output_shape))]))

# %%
# chú thích tính sự khác nhau giữa 2 model
def difference_models_norm_2(model_1, model_2):
    """Return the norm 2 difference between the two model parameters
    """
    
    tensor_1=list(model_1.parameters())
    tensor_2=list(model_2.parameters())
    
    norm=sum([torch.sum((tensor_1[i]-tensor_2[i])**2) for i in range(len(tensor_1))])
    
    return norm

# %%
def loss_dataset(model, dataset, loss_fn):
    """Compute the loss of `model` on `dataset`"""
    train_loss=0
    
    for batch,(X,y) in enumerate(dataset):
        X,y = X.to(device), y.to(device)
        optimizer.zero_grad()
        
        y_pred_logit = model(X)
        
        loss = loss_fn(y_pred_logit, y)
        train_loss += loss.item()
    
    train_loss = train_loss/len(dataset)
    return train_loss

# %%
def train_step_FD_Prox(model, model_0,mu:int,optimizer, dataloader,loss_fn):
    
    model.train()
    
    train_loss = 0.
    train_accuracy = 0.
    
    for batch,(X,y) in enumerate(dataloader):
        X,y = X.to(device), y.to(device)
        optimizer.zero_grad()
        
        y_pred_logit = model(X)
        
        loss = loss_fn(y_pred_logit, y)
        
        #thêm
        loss+=mu/2*difference_models_norm_2(model,model_0)
        
        train_loss += loss.item()
        
        loss.backward()
        optimizer.step()
        
    '''y_pred_prob = torch.softmax(y_pred_logit, dim = 1)
        y_pred_class = torch.argmax(y_pred_prob, dim = 1)
        train_accuracy += accuracy_score(y.cpu().numpy(), 
                                         y_pred_class.detach().cpu().numpy())'''
        
    train_loss = train_loss/len(dataloader)
    #train_accuracy = train_accuracy/len(dataloader)
    
    return train_loss

# %%
def local_learning(model, mu:float, optimizer, train_data, epochs:int, loss_f):
    
    model_0=deepcopy(model)
    
    for e in range(epochs):
        local_loss=train_step_FD_Prox(model,model_0,mu,optimizer,train_data,loss_f)
        
    return local_loss

# %%
def set_to_zero_model_weights(model):
    """Set all the parameters of a model to 0"""

    for layer_weigths in model.parameters():
        layer_weigths.data.sub_(layer_weigths.data)

# %%
def average_models(model, clients_models_hist:list , weights:list):


    """Creates the new model of a given iteration with the models of the other
    clients"""
    
    new_model=deepcopy(model)
    set_to_zero_model_weights(new_model)

    for k,client_hist in enumerate(clients_models_hist):
        
        for idx, layer_weights in enumerate(new_model.parameters()):

            contribution=client_hist[idx].data*weights[k]
            layer_weights.data.add_(contribution)
            
    return new_model

# %%
def train_FD_Prox(model, training_sets, epochs, mu,device,n_iter,lr,decay):
    #Variables initialization
    loss_fn = nn.CrossEntropyLoss() 
    K=len(training_sets) #number of clients
    n_samples=sum([len(db.dataset) for db in training_sets])
    weights=([len(db.dataset)/n_samples for db in training_sets])
    
    train_loss = [[float(loss_dataset(model, dl, loss_fn)) for dl in training_sets]]
    #######################################################################################
       
    
    
    server_loss=sum([weights[i]*train_loss[-1][i] for i in range(len(weights))])
    print(f'====> i: 0 Loss: {server_loss}')
    
    
    #########################################################################################
    for i in range(n_iter):
        
        clients_params=[] # tham số từng node
        clients_models=[] # model đc cập nhật ở từng node
        clients_losses=[] # loss từng node
        
        for k in range(K):
            
            local_model=deepcopy(model)
            local_optimizer=optim.Adam(local_model.parameters(),lr=lr)
            
            local_loss=local_learning(local_model,mu,local_optimizer, training_sets[k],epochs,loss_fn)
            clients_losses.append(local_loss)
                
            #GET THE PARAMETER TENSORS OF THE MODEL
            list_params=list(local_model.parameters())
            list_params=[tens_param.detach() for tens_param in list_params]
            clients_params.append(list_params)    
            clients_models.append(deepcopy(local_model))
        # tạo ra mô hình toàn cầu mới
        
        model = average_models(deepcopy(model), clients_params, weights=weights)
        #models_hist.append(clients_models)
        
        # TÍNH TOÁN MẤT/ĐỘ CHÍNH XÁC CỦA CÁC KHÁCH HÀNG KHÁC NHAU BẰNG MÔ HÌNH MỚI
        train_loss+=[[float(loss_dataset(model, dl, loss_fn)) for dl in training_sets]]
        server_loss=sum([weights[i]*train_loss[-1][i] for i in range(len(weights))])

        print(f'====> i: {i+1} Loss: {server_loss}')
        lr*=decay
    
    
    return model,train_loss

# %%
EPOCHS = 15

#torch.cuda.manual_seed(SEED)
#torch.manual_seed(SEED)

MODEL_RESULTS_FD , loss = train_FD_Prox(model.to(device), training_sets, EPOCHS,mu=args.mu,device=args.device,n_iter=args.n_iter,lr=args.lr, decay=1)
# Out:
# ====> i: 0 Loss: 1.1730588594179472
# ====> i: 1 Loss: 1.1052018288241916
# ====> i: 2 Loss: 1.089300843724087
# ====> i: 3 Loss: 1.0801455306777221
# ====> i: 4 Loss: 1.0731021419382785
# ====> i: 5 Loss: 1.0670395687724767
# ====> i: 6 Loss: 1.0615614577051533
# ====> i: 7 Loss: 1.0564978103576466
# ====> i: 8 Loss: 1.0517079966026173
# ====> i: 9 Loss: 1.047099118248035
# ====> i: 10 Loss: 1.0426865362145163
# ====> i: 11 Loss: 1.0384280559147916
# ====> i: 12 Loss: 1.0343151369025965
# ====> i: 13 Loss: 1.030288752258111
# ====> i: 14 Loss: 1.0264295195117232
# ====> i: 15 Loss: 1.0226140724521962

# %%
plt.plot(loss)
# Out:
# [<matplotlib.lines.Line2D at 0x78c83a9db790>,
#  <matplotlib.lines.Line2D at 0x78c83a9d9240>,
#  <matplotlib.lines.Line2D at 0x78c83a9da980>,
#  <matplotlib.lines.Line2D at 0x78c83a9d9900>,
#  <matplotlib.lines.Line2D at 0x78c8f23a6230>]

# %% [markdown]
# ## 4.3 Dự đoán đánh giá bằng model học liên kết

# %%
torch.save(MODEL_RESULTS_FD.state_dict(), '/kaggle/working/my_model_FDProx.pth')

# %%
# We define the model again with its respective modification.
loaded_model = vit_b_16()

loaded_model.heads = nn.Sequential(OrderedDict([('head',nn.Linear(in_features = 768, 
                                                                  out_features = output_shape))]))

loaded_model.load_state_dict(torch.load('/kaggle/working/my_model_FDProx.pth'))

# We now infer
loaded_model.to(device)

loaded_model.eval()

y_pred_test = []

with torch.inference_mode():
    for X,y in tqdm(test_dataloader):
        X,y = X.to(device), y.to(device)
        y_pred_logit = loaded_model(X)
        y_pred_prob = torch.softmax(y_pred_logit, dim = 1)
        y_pred_class = torch.argmax(y_pred_prob, dim = 1)
        y_pred_test.append(y_pred_class.detach().cpu())
# Out:
#   0%|          | 0/134 [00:00<?, ?it/s]

# %%
y_pred_test = torch.cat(y_pred_test).numpy()

# %%
print(f'Accuracy = {round(accuracy_score(df_test["label"].map(label_map), y_pred_test), 4)}')
# Out:
# Accuracy = 0.3657

# %%
confusion_matrix_test = confusion_matrix(df_test["label"].map(label_map), y_pred_test)

# %%
fig,ax = plt.subplots(figsize = (15,4))
sns.heatmap(confusion_matrix_test, 
            cmap = 'coolwarm', 
            annot = True, 
            annot_kws = {"fontsize":9, "fontweight":"bold"}, 
            linewidths = 1.2, 
            linecolor = "black", 
            square = True, 
            xticklabels = classes, 
            yticklabels = classes, 
            cbar = False,
            ax = ax)
ax.set_title("Confusion Matrix Test", fontsize = 10, fontweight = "bold", color = "darkblue")
ax.tick_params('x',rotation = 90)
fig.show()
